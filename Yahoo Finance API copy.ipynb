# %%
import pandas as pd

# %%
#import yahoo finance API
# !pip install yahoo_fin

# %%
#install necessary library
# !pip install requests_html

# %%
#Import models and methods of yahoo finance API
import yahoo_fin.stock_info as si
from yahoo_fin.stock_info import get_data
import yahoo_fin.stock_info as si

# %%
#employ company list methods to import list of Dow Jones 30 companies 
dow_list = si.tickers_dow()
print("Tickers in dw:", len(dow_list))
dow_list
# Out:
# Tickers in dw: 30
# ['AAPL',
#  'AMGN',
#  'AXP',
#  'BA',
#  'CAT',
#  'CRM',
#  'CSCO',
#  'CVX',
#  'DIS',
#  'DOW',
#  'GS',
#  'HD',
#  'HON',
#  'IBM',
#  'INTC',
#  'JNJ',
#  'JPM',
#  'KO',
#  'MCD',
#  'MMM',
#  'MRK',
#  'MSFT',
#  'NKE',
#  'PG',
#  'TRV',
#  'UNH',
#  'V',
#  'VZ',
#  'WBA',
#  'WMT']

# %%
#use imported model to get a dictionary 10 years historical stock price data of Dow Jones 30 companies
dow_historical = {}
for ticker in dow_list:
    dow_historical[ticker] = si.get_data(ticker, start_date="03/30/2013", end_date="03/30/2023", interval="1d")
dow_historical
# Out:
# {'AAPL':                   open        high         low       close    adjclose  \
#  2013-04-01   15.782143   15.846429   15.276429   15.318214   13.230055
#  2013-04-02   15.271429   15.647857   15.228571   15.349643   13.257195
#  2013-04-03   15.406071   15.617143   15.368214   15.428214   13.325053
#  2013-04-04   15.491429   15.535714   15.187500   15.275714   13.193346
#  2013-04-05   15.160714   15.176786   14.988571   15.114286   13.053923
#  ...                ...         ...         ...         ...         ...
#  2023-03-23  158.830002  161.550003  157.679993  158.929993  158.929993
#  2023-03-24  158.860001  160.339996  157.850006  160.250000  160.250000
#  2023-03-27  159.940002  160.770004  157.869995  158.279999  158.279999
#  2023-03-28  157.970001  158.490005  155.979996  157.649994  157.649994
#  2023-03-29  159.369995  161.050003  159.350006  160.770004  160.770004
#
#                 volume ticker
#  2013-04-01  389732000   AAPL
#  2013-04-02  529519200   AAPL
# ...

# %%
#transform disctonary to pandas.dataframe
combined_stats = pd.concat(dow_historical)
combined_stats = combined_stats.reset_index()
combined_stats
combined_stats.rename(columns = {'level_0':'company', 'level_1':'date'}, inplace = True)
combined_stats
# Out:
#       company       date        open        high         low       close  \
# 0        AAPL 2013-04-01   15.782143   15.846429   15.276429   15.318214
# 1        AAPL 2013-04-02   15.271429   15.647857   15.228571   15.349643
# 2        AAPL 2013-04-03   15.406071   15.617143   15.368214   15.428214
# 3        AAPL 2013-04-04   15.491429   15.535714   15.187500   15.275714
# 4        AAPL 2013-04-05   15.160714   15.176786   14.988571   15.114286
# ...       ...        ...         ...         ...         ...         ...
# 74032     WMT 2023-03-23  140.199997  141.610001  139.490005  140.649994
# 74033     WMT 2023-03-24  141.009995  142.470001  140.600006  141.800003
# 74034     WMT 2023-03-27  142.789993  144.979996  142.779999  144.169998
# 74035     WMT 2023-03-28  143.649994  144.410004  143.050003  143.610001
# 74036     WMT 2023-03-29  144.369995  144.960007  143.449997  144.229996
#
#          adjclose     volume ticker
# 0       13.230055  389732000   AAPL
# ...

# %%
#drop unnecessary column
dw_jones_30_10years = combined_stats.drop(['company'], axis=1)
dw_jones_30_10years
# Out:
#             date        open        high         low       close    adjclose  \
# 0     2013-04-01   15.782143   15.846429   15.276429   15.318214   13.230055
# 1     2013-04-02   15.271429   15.647857   15.228571   15.349643   13.257195
# 2     2013-04-03   15.406071   15.617143   15.368214   15.428214   13.325053
# 3     2013-04-04   15.491429   15.535714   15.187500   15.275714   13.193346
# 4     2013-04-05   15.160714   15.176786   14.988571   15.114286   13.053923
# ...          ...         ...         ...         ...         ...         ...
# 74032 2023-03-23  140.199997  141.610001  139.490005  140.649994  140.649994
# 74033 2023-03-24  141.009995  142.470001  140.600006  141.800003  141.800003
# 74034 2023-03-27  142.789993  144.979996  142.779999  144.169998  144.169998
# 74035 2023-03-28  143.649994  144.410004  143.050003  143.610001  143.610001
# 74036 2023-03-29  144.369995  144.960007  143.449997  144.229996  144.229996
#
#           volume ticker
# ...

# %%
#create unique id for each row
df['id'] = range(len(df))
dw_jones_30_10years ['id'] = range(len(dw_jones_30_10years))
dw_jones_30_10years
# Out:
#             date        open        high         low       close    adjclose  \
# 0     2013-04-01   15.782143   15.846429   15.276429   15.318214   13.230053
# 1     2013-04-02   15.271429   15.647857   15.228571   15.349643   13.257196
# 2     2013-04-03   15.406071   15.617143   15.368214   15.428214   13.325056
# 3     2013-04-04   15.491429   15.535714   15.187500   15.275714   13.193348
# 4     2013-04-05   15.160714   15.176786   14.988571   15.114286   13.053924
# ...          ...         ...         ...         ...         ...         ...
# 74032 2023-03-23  140.199997  141.610001  139.490005  140.649994  140.649994
# 74033 2023-03-24  141.009995  142.470001  140.600006  141.800003  141.800003
# 74034 2023-03-27  142.789993  144.979996  142.779999  144.169998  144.169998
# 74035 2023-03-28  143.649994  144.410004  143.050003  143.610001  143.610001
# 74036 2023-03-29  144.369995  144.960007  143.449997  144.229996  144.229996
#
#           volume ticker     id
# ...

# %%
#Export dataframe as CSV file
dw_jones_30_10years.to_csv('dawjones_tenyears1.csv', index=False)

# %%
#convert CSV to JSON format
import csv
import json
 
 

def make_json(csvFilePath, jsonFilePath):
     
  
    data = {}
     
    
    with open(csvFilePath, encoding='utf-8') as csvf:
        csvReader = csv.DictReader(csvf)
         
        
        for rows in csvReader:
             
            
            key = rows['id']
            data[key] = rows
 
   
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf:
        jsonf.write(json.dumps(data, indent=4))
         

csvFilePath = r'dawjones_tenyears1.csv'
jsonFilePath = r'dawjones_tenyears2.json'
 

make_json(csvFilePath, jsonFilePath)
